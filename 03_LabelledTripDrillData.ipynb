# %%
import pandas as pd

# %%
Label_Raw_DB_filename = "Data\\Master_Report\\RAW-REPORT-RTOC-AAE-06_12-5in_Rev1-3.xlsx"

Label_Raw_DB = pd.read_excel(Label_Raw_DB_filename)
print(Label_Raw_DB.dtypes)
Label_Raw_DB
# Out:
# Date                   datetime64[ns]
# Time                           object
# Date/Time              datetime64[ns]
# Connection Activity            object
# Sub Activity                   object
# Activity                       object
# Remarks                        object
# dtype: object
#           Date      Time           Date/Time Connection Activity  \
# 0   2021-09-01  20:50:33 2021-09-01 20:50:33                 NaN
# 1   2021-09-01  23:19:04 2021-09-01 23:19:04                 NaN
# 2   2021-09-01  23:26:44 2021-09-01 23:26:44                 NaN
# 3   2021-09-01  23:30:04 2021-09-01 23:30:04                 NaN
# 4   2021-09-01  23:33:24 2021-09-01 23:33:24                 NaN
# ..         ...       ...                 ...                 ...
# 973 2021-09-17  11:00:00 2021-09-17 11:00:00                 NaN
# 974 2021-09-17  12:30:00 2021-09-17 12:30:00                 NaN
# 975 2021-09-17  16:20:00 2021-09-17 16:20:00                 NaN
# ...

# %%
RT_Raw_DB_filename = "Data\\Merged\\Merge_DrillTrip_AAE-06.csv"

RT_Raw_DB = pd.read_csv(RT_Raw_DB_filename)
list_column = ["dt_DF",
                "dt",
                "date",
                "time",
                "bitdepth",
                "md",
                "blockpos",
                "rop",
                "hklda",
                "woba",
                "torqa",
                "rpm",
                "stppress",
                "mudflowin",
                "Remarks",
                "dt",
                "SubActivity_Predict"]
RT_Raw_DB = RT_Raw_DB[list_column]
RT_Raw_DB.rename(columns = {'Remarks':'MajorActivity'}, inplace = True)
print(RT_Raw_DB.dtypes)
RT_Raw_DB
# Out:
# dt_DF                   object
# dt                      object
# date                    object
# time                    object
# bitdepth               float64
# md                     float64
# blockpos               float64
# rop                    float64
# hklda                  float64
# woba                   float64
# torqa                  float64
# rpm                    float64
# stppress               float64
# mudflowin              float64
# MajorActivity           object
# dt                      object
# SubActivity_Predict     object
# dtype: object
#                       dt_DF              dt       date     time  bitdepth  \
# 0       2021-08-22 00:00:04  8/22/2021 0:00  8/22/2021  0:00:04     10.58
# 1       2021-08-22 00:00:09  8/22/2021 0:00  8/22/2021  0:00:09     10.58
# 2       2021-08-22 00:00:14  8/22/2021 0:00  8/22/2021  0:00:14     10.58
# 3       2021-08-22 00:00:19  8/22/2021 0:00  8/22/2021  0:00:19     10.58
# ...

# %%
#check min max
print(str(RT_Raw_DB['dt_DF'].min()) + " - " + str(RT_Raw_DB['dt_DF'].max()))
print(str(Label_Raw_DB['Date/Time'].min()) + " - " + str(Label_Raw_DB['Date/Time'].max()))
# Out:
# 2021-08-22 00:00:04 - 2021-08-29 01:00:00
# 2021-09-01 20:50:33 - 2021-09-18 00:00:00

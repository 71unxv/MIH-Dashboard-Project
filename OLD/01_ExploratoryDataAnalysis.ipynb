# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

from IPython.display import display as displayDF

# %%
Realtime_DB_LABELED = pd.read_csv("FinalLabelDataAll.csv",index_col=0)
displayDF(Realtime_DB_LABELED.head())
for i in (Realtime_DB_LABELED.columns):
    print(i)
# Out:
# C:\Users\irsya\Miniconda3\envs\python36\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (150,151,152) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                     dt  wid  sid  recid  seqid        date      time  actcode  \
# 0  2021-04-26 10:45:28  143    0      1  32767  2021-04-26  10:45:28        2
# 1  2021-04-26 10:45:33  143    0      1  32767  2021-04-26  10:45:33        2
# 2  2021-04-26 10:46:36  143    0      1  32767  2021-04-26  10:46:36        2
# 3  2021-04-26 10:46:41  143    0      1  32767  2021-04-26  10:46:41        2
# 4  2021-04-26 10:46:46  143    0      1  32767  2021-04-26  10:46:46        2
#
#    blockpos  bitdepth  ...  spare_5  spare_6  spare_7  spare_8  spare_9  \
# 0      4.33      62.7  ...      0.0      0.0      0.0    63.79      0.0
# 1      4.33      62.7  ...      0.0      0.0      0.0    63.79      0.0
# ...

# %%
List_feature = ['LABEL_ConnectionActivity',	'LABEL_SubActivity',	'LABEL_Activity',
    "blockpos",	"bitdepth",								
"deptbitv",	"md",	"tvd",	"speedup",	"speeddown",	"rop",	"ropi",	"hklda",	"hkldx",	"woba",
"wobx",	"torqa",	"torqx",	"torqp",	"rpm",	"rpmm",	"totrpm",	"stppress",	"csgpress",	"mudflowin",
"mudflowout",	"mudflowoutp",	"muddensin",	"muddensout",	"mudtempin",	"mudtempout",	"mfiann",	"surfrev",	"drillrev",	"reamrev",
"circrev",	"totrev",	"drilltime",	"reamtime",	"circtime",	"pumptime",	"drilldist",	"totspm",	"totpumpvol",	"tankvolact",
"tankvolchgact",	"ecddpt",	"ecdbit",	"ecdshoe",	"deptretm",	"lagtime",	"dnhstroke",	"dnhtime",	"mse",	"gas",
"dstrength",	"mseds",	"bht",	"scfm",	"airflin",	"airfloutp",	"airflout",	"airpress",	"airtemp",	"whp",
"h2s2",	"h2s3",	"bitsize",	"foamrate",	"spare_1",	"spare_4",	"spare_5",	"spare_6",	"spare_7",	"spare_8",
]

# %%
List_Label = ['LABEL_ConnectionActivity',	'LABEL_SubActivity',	'LABEL_Activity']

MeanSummary = Realtime_DB_LABELED.groupby(List_Label).agg( ['mean','min','max','median']).reset_index()
displayDF(MeanSummary[List_feature])
# Out:
#    LABEL_ConnectionActivity LABEL_SubActivity      LABEL_Activity   blockpos  \
#                                                                         mean
# 0                Connection        Connection    Drill Out Cement   9.802361
# 1                Connection        Connection  Drilling Formation  23.144286
# 2                Connection        Connection   Running Casing In  11.761798
# 3                Connection        Connection             Trip In  17.706677
# 4                Connection        Connection            Trip Out  23.312702
# ..                      ...               ...                 ...        ...
# 75           Pre Connection           Reaming    Drill Out Cement  17.505226
# 76           Pre Connection           Reaming  Drilling Formation  15.840218
# 77           Pre Connection           Reaming   Running Casing In  12.818244
# 78           Pre Connection           reaming  Drilling Formation  14.432381
# ...

# %%
MeanSummary[List_feature].to_excel("EDA_MeanSummary.xlsx", engine='openpyxl')
